# %%
import pandas as pd
file=''

# %%
import os 
directory = os.getcwd()

# %%
splitted = directory.split('\\')

for x in range(len(splitted)-1):
    file += splitted[x]
    file += '/'
file_csv = file + 'Dataset/final_data.csv'


df = pd.read_csv(file_csv)
df.head(10)
# Out:
#        director_name     actor_1_name       actor_2_name
# 0      James Cameron      CCH Pounder   Joel David Moore  \
# 1     Gore Verbinski      Johnny Depp      Orlando Bloom
# 2         Sam Mendes  Christoph Waltz       Rory Kinnear
# 3  Christopher Nolan        Tom Hardy     Christian Bale
# 4        Doug Walker      Doug Walker         Rob Walker
# 5     Andrew Stanton     Daryl Sabara    Samantha Morton
# 6       Nathan Greno     Brad Garrett       Donna Murphy
# 7        Joss Whedon  Chris Hemsworth  Robert Downey Jr.
# 8        David Yates     Alan Rickman   Daniel Radcliffe
# 9        Zack Snyder     Henry Cavill       Lauren Cohan
#
#            actor_3_name                                             genres
# 0             Wes Studi                    Action Adventure Fantasy Sci-Fi  \
# 1        Jack Davenport                           Action Adventure Fantasy
# 2      Stephanie Sigman                          Action Adventure Thriller
# 3  Joseph Gordon-Levitt                                    Action Thriller
# 4               unknown                                        Documentary
# 5          Polly Walker                            Action Adventure Sci-Fi
# 6           M.C. Gainey  Adventure Animation Comedy Family Fantasy Musi...
# 7    Scarlett Johansson                            Action Adventure Sci-Fi
# 8          Rupert Grint                   Adventure Family Fantasy Mystery
# 9        Alan D. Purwin                            Action Adventure Sci-Fi
#
#                                          movie_title
# 0                                             avatar  \
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# 4  star wars: episode vii - the force awakens    ...
# 5                                        john carter
# 6                                            tangled
# 7                            avengers: age of ultron
# 8             harry potter and the half-blood prince
# 9                 batman v superman: dawn of justice
#
#                                                 comb
# 0  CCH Pounder Joel David Moore Wes Studi James C...
# 1  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4  Doug Walker Rob Walker unknown Doug Walker Doc...
# 5  Daryl Sabara Samantha Morton Polly Walker Andr...
# 6  Brad Garrett Donna Murphy M.C. Gainey Nathan G...
# 7  Chris Hemsworth Robert Downey Jr. Scarlett Joh...
# 8  Alan Rickman Daniel Radcliffe Rupert Grint Dav...
# 9  Henry Cavill Lauren Cohan Alan D. Purwin Zack ...

# %%
#Below is the json payload from the age of empires game

file_json =  file + 'Dataset/icons.json'

df1 = pd.read_json(file_json)
df1.head(1000)
# Out:
#                          Buildings              Units
# 0    BuildingIcons000ArcheryRange1  UnitIcons00050730  \
# 1    BuildingIcons001ArcheryRange3  UnitIcons00150730
# 2        BuildingIcons002Barracks1  UnitIcons00250730
# 3        BuildingIcons003Barracks3  UnitIcons00350730
# 4      BuildingIcons004Blacksmith1  UnitIcons00450730
# ..                             ...                ...
# 399                            NaN  UnitIcons39950730
# 400                            NaN  UnitIcons40050730
# 401                            NaN  UnitIcons40150730
# 402                            NaN  UnitIcons40250730
# 403                            NaN  UnitIcons40350730
#
#                          Techs
# 0    TechIconsT000CropRotation
# 1       TechIconsT001HeavyPlow
# 2     TechIconsT002HorseCollar
# 3         TechIconsT003Banking
# 4     TechIconsT004Cartography
# ..                         ...
# 399                        NaN
# 400                        NaN
# 401                        NaN
# 402                        NaN
# 403                        NaN
#
# [404 rows x 3 columns]

# %%
#Below is the xml file from the F1 22 game
# Install a pip package in the current Jupyter kernel
import sys

try:
    # !{sys.executable} -m pip install lxml
except:
    pass

file_xml =  file + 'Dataset/logitech_g923_ps.xml'
df3 = pd.read_xml(file_xml)

df3.head()
# Out:
# Collecting lxml
#   Downloading lxml-4.9.2-cp39-cp39-win_amd64.whl (3.9 MB)
#      ---------------------------------------- 3.9/3.9 MB 1.4 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-4.9.2
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\Users\kaush\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[11], line 11
#     df3 = pd.read_xml(file_xml)
#
#   File c:\Users\kaush\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\xml.py:1118 in read_xml
#     return _parse(
#
#   File c:\Users\kaush\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\xml.py:844 in _parse
#     data_dicts = p.parse_data()
#
#   File c:\Users\kaush\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\xml.py:564 in parse_data
#     self.xml_doc = self._parse_doc(self.path_or_buffer)
#
#   File c:\Users\kaush\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\xml.py:655 in _parse_doc
#     document = fromstring(
#
#   File src\lxml\etree.pyx:3257 in lxml.etree.fromstring
#
#   File src\lxml\parser.pxi:1916 in lxml.etree._parseMemoryDocument
#
#   File src\lxml\parser.pxi:1803 in lxml.etree._parseDoc
#
#   File src\lxml\parser.pxi:1144 in lxml.etree._BaseParser._parseDoc
#
#   File src\lxml\parser.pxi:618 in lxml.etree._ParserContext._handleParseResultDoc
#
#   File src\lxml\parser.pxi:728 in lxml.etree._handleParseResult
#
#   File src\lxml\parser.pxi:657 in lxml.etree._raiseParseError
#
#   File <string>:234
# XMLSyntaxError: attributes construct error, line 234, column 26

# %%
#Below is the sample sql file
file_sql =  file + 'Dataset/Sample-SQL-File-1000rows.sql'
df4 = pd.read_sql_query(file_sql,con='')

df4.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 3
#       1 #Below is the sample sql file
#       2 file_sql =  file + 'Dataset/Sample-SQL-File-1000rows.sql'
# ----> 3 df4 = pd.read_sql_query(file_sql,con='')
#       5 df4.head()
#
# File c:\Users\kaush\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py:466, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     463 if dtype_backend is lib.no_default:
#     464     dtype_backend = "numpy"  # type: ignore[assignment]
# --> 466 with pandasSQL_builder(con) as pandas_sql:
#     467     return pandas_sql.read_query(
#     468         sql,
#     469         index_col=index_col,
#    (...)
#     475         dtype_backend=dtype_backend,
#     476     )
#
# File c:\Users\kaush\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py:827, in pandasSQL_builder(con, schema, need_transaction)
#     824 sqlalchemy = import_optional_dependency("sqlalchemy", errors="ignore")
#     826 if isinstance(con, str) and sqlalchemy is None:
# --> 827     raise ImportError("Using URI string without sqlalchemy installed.")
#     829 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
#     830     return SQLDatabase(con, schema, need_transaction)
#
# ImportError: Using URI string without sqlalchemy installed.
